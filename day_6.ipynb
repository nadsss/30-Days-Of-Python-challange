# %%
mytuple = ()

# %%
sis = ("gehad", "salma", "alaa")

# %%
brothers = ("ahmed",)

# %%
sip = sis + brothers

# %%
print(len(sip))
# Out:
# 4

# %%
lis = list(sip)

# %%
lis.append("mom")

# %%
lis.append("dad")

# %%
family = tuple(lis)
