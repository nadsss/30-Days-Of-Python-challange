# %%
#Get the current day, month, year, hour, minute and timestamp from datetime module
from datetime import datetime, date

# %%
today = datetime.today()
print(today)
# Out:
# 2026-09-14 17:40:52.749665

# %%
#Format the current date using this format: "%m/%d/%Y, %H:%M:%S")
now = datetime.now()
print(now.strftime("%m/%d/%Y, %H:%M:%S"))
# Out:
# 09/14/2026, 17:54:59

# %%
#Today is 5 December, 2019. Change this time string to time.
today = "5 December, 2019"
print(datetime.strptime(today,"%d %B, %Y"))
# Out:
# 2019-12-05 00:00:00

# %%
#Calculate the time difference between now and new year.
today = date(2026,9,14)
new_year = date(2027,1,1)
print(new_year - today)
# Out:
# 109 days, 0:00:00

# %%
#Calculate the time difference between 1 January 1970 and now.
date_5 = datetime.strptime("1, January, 1970", "%d, %B, %Y")
print(f"Time difference between now ({now.strftime("%Y-%m-%d %H:%M:%S")}) and {date_5.strftime("%Y-%m-%d %H:%M:%S")} = {now - date_5})")
# Out:
# Time difference between now (2026-09-14 17:54:59) and 1970-01-01 00:00:00 = 20710 days, 17:54:59.647289)
