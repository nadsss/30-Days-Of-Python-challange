# %%
dog = dict()

# %%
dog["name"] = "loka"

# %%
dog["color"] = "golden"

# %%
dog["breed"] = "golden retriever"

# %%
dog["legs"] = 4

# %%
dog["age"] = 2

# %%
student = {
    "first name": "nad",
    "last name": "mo",
    "gender": "female",
    "age": 24,
    "marital status": "single",
    "skills": ["python","statistics"],
    "country": "egypt",
    "city": "cairo",
    "address": "sauigdas"
}

# %%
print(len(student))
# Out:
# 9

# %%
print(student["skills"],type(student["skills"]))
# Out:
# ['python', 'statistics'] <class 'list'>

# %%
student["skills"].append("math")

# %%
student.keys()
# Out:
# dict_keys(['first name', 'last name', 'gender', 'age', 'marital status', 'skills', 'country', 'city', 'address'])

# %%
student.values()
# Out:
# dict_values(['nad', 'mo', 'female', 24, 'single', ['python', 'statistics', 'math'], 'egypt', 'cairo', 'sauigdas'])

# %%
student.items()
# Out:
# dict_items([('first name', 'nad'), ('last name', 'mo'), ('gender', 'female'), ('age', 24), ('marital status', 'single'), ('skills', ['python', 'statistics', 'math']), ('country', 'egypt'), ('city', 'cairo'), ('address', 'sauigdas')])

# %%
student.pop("skills")
# Out:
# ['python', 'statistics', 'math']

# %%
del student
