# %%
import math

# %%
age = 24

# %%
height = 165.0

# %%
cmplx = 5 + 4j

# %%
base = float(input("enter base:"))
# Out:
# enter base: 20

# %%
h = float(input("enter height:"))
# Out:
# enter height: 10

# %%
area = 0.5 * base * h

# %%
print(f"the area of the triangle is {area}")
# Out:
# the area of the triangle is 100.0

# %%
a = float(input("enter side a:"))
# Out:
# enter side a: 5

# %%
b = float(input("enter side b:"))
# Out:
# enter side b: 4

# %%
c = float(input("enter side c:"))
# Out:
# enter side c: 3

# %%
per = a+b+c

# %%
print(f"the perimeter of the triangle is {per}")
# Out:
# the perimeter of the triangle is 12.0

# %%
length = float(input("enter length:"))
# Out:
# enter length: 5

# %%
width = float(input("enter width:"))
# Out:
# enter width: 5

# %%
area = length * width

# %%
perimeter = 2 * (length + width)

# %%
print(f"the area of the rectangle is {area} and the perimeter is {perimeter}")
# Out:
# the area of the rectangle is 25.0 and the perimeter is 20.0

# %%
slope = 2

# %%
x_inter = 1

# %%
y_inter = -2

# %%
m = (10-2) / (6-2)

# %%
euc = math.sqrt((6-2)**2 + (10-2)**2)

# %%
print(slope == m)
# Out:
# True

# %%
x = -3

# %%
print(x**2 + 6*x + 9)
# Out:
# 0

# %%
print(len("python") == len("dragon"))
# Out:
# True

# %%
print ("on" in "python" and "on" in "dragon")
# Out:
# True

# %%
print("jargon" in "I hope this course is not full of jargon")
# Out:
# True

# %%
print("no" in "dragon" and "no" in "python")
# Out:
# False

# %%
print(str(float(len("python"))))
# Out:
# 6.0

# %%
y = 3

# %%
print("even" if y%2 == 0 else "odd")
# Out:
# odd

# %%
print( 7//3 == int(2.7))
# Out:
# True

# %%
print(type('10')==type(10))
# Out:
# False
