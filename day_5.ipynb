# %%
x = []

# %%
x = [1, 2, 3, 4, 5, 6,7]

# %%
print(len(x))
# Out:
# 7

# %%
print(x[0])
# Out:
# 1

# %%
print(x[-1])
# Out:
# 7

# %%
print(x[len(x)//2])
# Out:
# 4

# %%
it_companies = ["Facebook", "Google", "Microsoft", "Apple", "IBM", "Oracle" , "Amazon"]

# %%
print(it_companies)
# Out:
# ['Facebook', 'Google', 'Microsoft', 'Apple', 'IBM', 'Oracle', 'Amazon']

# %%
it_companies[0] = "meta"

# %%
print(it_companies)
# Out:
# ['meta', 'Google', 'Microsoft', 'Apple', 'IBM', 'Oracle', 'Amazon']

# %%
it_companies.append("openAi")

# %%
it_companies.insert(4,"valeo")

# %%
it_companies[0] = it_companies[0].upper()

# %%
print("#; ".join(it_companies))
# Out:
# META#; Google#; Microsoft#; Apple#; valeo#; IBM#; Oracle#; Amazon#; openAi

# %%
print("META" in it_companies)
# Out:
# True

# %%
it_companies.sort()

# %%
it_companies.reverse()

# %%
print(it_companies[3:])
# Out:
# ['Microsoft', 'META', 'IBM', 'Google', 'Apple', 'Amazon']

# %%
print(it_companies[:-3])
# Out:
# ['valeo', 'openAi', 'Oracle', 'Microsoft', 'META', 'IBM']

# %%
print(it_companies.pop(0))
# Out:
# valeo

# %%
it_companies.clear()

# %%
del it_companies

# %%
it_companies
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 it_companies
#
# NameError: name 'it_companies' is not defined

# %%
front_end = ['HTML', 'CSS', 'JS', 'React', 'Redux']
back_end = ['Node','Express', 'MongoDB']

# %%
full_stack = front_end + back_end

# %%
full_stack.insert(5,"SQL")

# %%
full_stack.insert(6,"python")

# %%
full_stack
# Out:
# ['HTML',
#  'CSS',
#  'JS',
#  'React',
#  'Redux',
#  'SQL',
#  'python',
#  'Node',
#  'Express',
#  'MongoDB']

# %%
ages = [19, 22, 19, 24, 20, 25, 26, 24, 25, 24]

# %%
ages.sort()

# %%
print(min(ages),max(ages))
# Out:
# 19 26

# %%
ages
# Out:
# [19, 19, 20, 22, 24, 24, 24, 25, 25, 26]

# %%
median = 24+24/2

# %%
avg = sum(ages) / len(ages)

# %%
rnge = max(ages) - min(ages)

# %%
print(abs(min(ages)-avg) == abs(max(ages)-avg))
# Out:
# False

# %%
a,b,c, *scandic = ['China', 'Russia', 'USA', 'Finland', 'Sweden', 'Norway', 'Denmark']

# %%
scandic
# Out:
# ['Finland', 'Sweden', 'Norway', 'Denmark']
